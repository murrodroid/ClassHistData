# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv('../datasets/ICD10codes.csv')
df
# Out:
#       overcategory num_cat  ICD10  \
# 0              A00       0   A000
# 1              A00       1   A001
# 2              A00       9   A009
# 3             A010       0  A0100
# 4             A010       1  A0101
# ...            ...     ...    ...
# 71699         Z991       2  Z9912
# 71700         Z992     NaN   Z992
# 71701         Z993     NaN   Z993
# 71702         Z998       1  Z9981
# 71703         Z998       9  Z9989
#
#                                                    desc1  \
# 0      Cholera due to Vibrio cholerae 01, biovar chol...
# 1        Cholera due to Vibrio cholerae 01, biovar eltor
# 2                                   Cholera, unspecified
# 3                             Typhoid fever, unspecified
# 4                                     Typhoid meningitis
# ...                                                  ...
# 71699  Encounter for respirator dependence during pow...
# 71700                       Dependence on renal dialysis
# ...

# %%
def add_subcategory(df, target_col='ICD10', overcat_col='overcategory', output_col = 'subcategory'):
    df[output_col] = df.apply(
        lambda row: row[target_col][len(row[overcat_col]):],
        axis=1
    )
    return df

df = add_subcategory(df)

# %%
def add_processed_desc(df, target_col='desc1', output_col = 'desc_processed'):
    df[output_col] = df.apply(
        lambda row: re.sub(r'[^a-z0-9 ]', '', row[target_col].lower()),
        axis=1
    )
    return df

df = add_processed_desc(df)

# %%
df
# Out:
#       overcategory num_cat  ICD10  \
# 0              A00       0   A000
# 1              A00       1   A001
# 2              A00       9   A009
# 3             A010       0  A0100
# 4             A010       1  A0101
# ...            ...     ...    ...
# 71699         Z991       2  Z9912
# 71700         Z992     NaN   Z992
# 71701         Z993     NaN   Z993
# 71702         Z998       1  Z9981
# 71703         Z998       9  Z9989
#
#                                                    desc1  \
# 0      Cholera due to Vibrio cholerae 01, biovar chol...
# 1        Cholera due to Vibrio cholerae 01, biovar eltor
# 2                                   Cholera, unspecified
# 3                             Typhoid fever, unspecified
# 4                                     Typhoid meningitis
# ...                                                  ...
# 71699  Encounter for respirator dependence during pow...
# 71700                       Dependence on renal dialysis
# ...
