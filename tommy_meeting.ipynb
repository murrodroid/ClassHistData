# %%
from pure_ml.modules.import_data import import_data_individualized, import_data_standard

# %%
df_ind, _ = import_data_individualized()
df_ind_labeled = df_ind[df_ind.icd10h.notna()]

df_std_labeled, df_std = import_data_standard()
# Out:
# c:\1_repos\ClassHistData\pure_ml\modules\import_data.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['icd10h_category', 'icd10h_subcategory']] = (df['icd10h'].str.split('.', n=1, expand=True))
# c:\1_repos\ClassHistData\pure_ml\modules\import_data.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['icd10h_category', 'icd10h_subcategory']] = (df['icd10h'].str.split('.', n=1, expand=True))

# %%
df_ind.shape, df_ind_labeled.shape
# Out:
# ((550024, 14), (474439, 14))

# %%
df_std.shape, df_std_labeled.shape
# Out:
# ((10556, 12), (2569, 12))

# %%
df_ind[df_ind.yearOfDeath < 1861].sample(20)
# Out:
#                             deathcause_mono  \
# 342099                                  nan
# 24                           hjernetilfælde
# 46                      underlivsbetændelse
# 72                        atrophia (atrofi)
# 11                          skarlagensfeber
# 50                            lungesvindsot
# 31                                   tæring
# 0                                  alderdom
# 8                            typhus (tyfus)
# 35                       febris puerperalis
# 17                        atrophia (atrofi)
# 4                     organisk hjertesygdom
# 43                                   tæring
# 5                               lungetæring
# 65                             hjertesygdom
# 20               barselfeber (barselsfeber)
# 29                       febris puerperalis
# 79                         hjernebetændelse
# 3081                                    nan
# 10      kulilteforgiftning (kulforgiftning)
#
# ...
